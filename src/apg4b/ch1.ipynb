# %% [markdown]
# # 47th KCLC (コンピュータ部)<br>講義 Chapter 1
#
# Chapter 1 では、1.00 ~ 1.05 を扱います。
# プログラミングでは必須となる基礎文法となるため、頑張って覚えましょう。
# **変数と型**という部分が、初学の場合には一番の壁となると思います。

# %% [markdown]
# ## 目次
#
# - [1.00.はじめに](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_a)
# - [1.01.出力とコメント](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_b)
# - [1.02.プログラムの書き方とエラー](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_c)
# - [1.03.四則演算と優先順位](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_d)
# - [1.04.変数と型](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_e)
# - [1.05.入力](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_f)

# %% [markdown]
# ## 講義の進め方
#
# 1. [資料置き場](https://github.com/ks-KCLC/course-intro-to-programming) にアクセス
# 2. [Google Colab](https://colab.research.google.com/?hl=ja) にアクセス
# 3. 「ノートブックを開く」ダイアログで「GitHub」を選択
# 4. [資料置き場](https://github.com/ks-KCLC/course-intro-to-programming)の URL (<https://github.com/ks-KCLC/course-intro-to-programming>) を入力して検索
# 5. 該当する講義回のノートブックをクリック (ex. `src/apg4b/ch1.ipynb`)
# 6. 開いたノートブック上で講義を進める

# %% [markdown]
# ## 1.00.はじめに
#
# 本編: [1.00.はじめに](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_a)
#
# ### プログラミング言語について
#
# - Python
# - C++
# - Scratch
#
# #### コンパイル言語 vs インタプリタ言語
#
# - プログラムのパフォーマンス
#   - 時間計算量
#   - 空間計算量
#
# #### Python vs Scratch
#
# <https://www.reddit.com/r/learnprogramming/comments/1ccr95z/which_is_better_to_learn_first_python_or_scratch/?tl=ja>
#
# > Pythonから始めるのがおすすめかな。Scratchは子供とか、視覚的に学びたい人にはすごくいいんだけど、Pythonの方が現実世界での応用範囲がずっと広いし、コミュニティも大きいんだよね。それに、Web開発とかデータサイエンスとか、もっと色んなことに使える汎用性の高い言語だし。
#
# **プログラミング言語は用途に応じて使い分けよう -> Python の用途は？**

# %% [markdown]
# ## 1.01.出力とコメント
#
# 本編: [1.01.出力とコメント](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_b)
#
# 練習問題: [コードテストと出力の練習](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_cv)
#
# 初めて練習問題が登場しました。
# 登録した AtCoder アカウントを使って、書いたコードを提出してみましょう！
# 言語は、"Python (CPython 3.13.7)" にしましょう。

# %%
print("Hello, KCLC!")

# %% [markdown]
# ## 1.02.プログラムの書き方とエラー
#
# 本編: [1.02.プログラムの書き方とエラー](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_c)
#
# 練習問題: [エラーの修正](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_cu)
#
# **`def`, `for`, `list` などは無視して OK (後でやります)**
# **`print` は復習しておこう**
#
# 「インデント」は Python では間違えるとエラーになってしまう重要な要素となります。
# ぜひ用語まで覚えていきましょう。

# %%
print("いつも2525"
    print(AtCoderくん)

# %% [markdown]
# ## 1.03.四則演算と優先順位
#
# 本編: [1.03.四則演算と優先順位](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_d)
#
# 練習問題: [計算問題](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_ct)
#
# `*`, `//`, `/`, `**`, `%` などは見覚えがないかも？
# キーボードで打てるようにもしておきましょう。
# 優先順位は基本的には算数/数学と同じです。

# %%
3 + 4

# %% [markdown]
# ## 1.04.変数と型
#
# 本編: [1.04.変数と型](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_e)
#
# 練習問題: [◯年は何秒？](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_cs)
#
# 変数は「メモ」、型は「データの種類」と説明されていますが、変数を「箱」などと説明する場合もあります。
# プログラミングにおいて非常に重要な概念なので、頑張って理解しましょう！
# ぜひ質問してください！

# %%
seconds = 365 * 24 * 60 * 60
print()  # 1年は何秒か出力
print()  # 2年は何秒か出力
print()  # 5年は何秒か出力
print()  # 10年は何秒か出力

# %% [markdown]
# ## 1.05.入力
#
# 本編: [1.05.入力](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_f)
#
# 練習問題: [A足すB問題](https://atcoder.jp/contests/APG4bPython/tasks/APG4bPython_cr)
#
# `split()` 関数が少し難しいかも。
# `input()` 関数は、一行の入力 (空白などを含んでも良い) を文字列として受け取る関数です。

# %%
s = input() # "Hello World"
a, b = input().split()
print(s, a, b)
